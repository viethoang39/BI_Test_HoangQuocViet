-- %% [markdown]
-- #### Câu 1.1: Sentiment Classification
-- Phân loại `nps_comment` thành 3 nhóm:
-- - **Positive** (tích cực)
-- - **Neutral** (trung lập)
-- - **Negative** (tiêu cực)

-- %%
with _temp as (
SELECT
    lower(regexp_replace(nps_comment, '(?i)\\b(ko|khong co|khong|kh|khong|khum|k|hông|khôg|hong|kg|khôbg|hôg|kjoong|ki)\\b', 'không')) as step1,
    regexp_replace(step1, '(?i)\\b(tot)\\b', 'tốt') AS nps_comment
FROM workspace.bi.nps_survey
)
select 
    nps_comment,
    ai_analyze_sentiment(nps_comment)
from _temp
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- Logic phân loại: tận dụng hàm ai_analyze_sentiment sẵn có của databricks để phân loại sentiment.
-- Document liên quan: https://docs.databricks.com/aws/en/sql/language-manual/functions/ai_analyze_sentiment
